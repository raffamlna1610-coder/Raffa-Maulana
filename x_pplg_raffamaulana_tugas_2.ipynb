# %% [markdown]
# <a href="https://colab.research.google.com/github/raffamlna1610-coder/Raffa-Maulana/blob/main/x_pplg_raffamaulana_tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Raffa maul (ganteng) : ";
#     cin >> namaSiswa;
#
#     cout << " tahun masih muda    : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata kamu masih muda ya,umurnya " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# Raffa maul (ganteng) : ganteng
#  tahun masih muda    : 17
#
# Halo ganteng, ternyata kamu masih muda ya,umurnya 17 tahun ya!
