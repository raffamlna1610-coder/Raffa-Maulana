# %% [markdown]
# <a href="https://colab.research.google.com/github/raffamlna1610-coder/Raffa-Maulana/blob/main/tugas_program_menghitung_keliling_persegi_panjang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR KELILING PERSEGI PANJANG
#
# kelompok NOVA CREW
# 1.Raffa maul
# 2.Ajril
# 3.Rizky
# 4.Dava mukhlis
# 5.cut afra
# 6.deliandra
# 7.adika median

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile kelilingpersegipanjang.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
# int p,l,keliling;
#  cout <<"massukan panjang"<<endl;
#  cin>>p;
#  cout <<"masukkan lebar"<<endl;
#  cin>>l;
#  keliling=2*p+l;
#  cout<<"keliling persegi panjang adalah "<<keliling<<endl;
# return 0;
# }
# Out:
# Overwriting kelilingpersegipanjang.cpp

# %%
# !g++ kelilingpersegipanjang.cpp -o main

# %%
! ./main
# Out:
# massukan panjang
# 10
# masukkan lebar
# 500
# keliling persegi panjang adalah 520
