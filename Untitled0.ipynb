# %% [markdown]
# <a href="https://colab.research.google.com/github/raffamlna1610-coder/Raffa-Maulana/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Raffa maul (ganteng) : ";
#     cin >> namaSiswa;
#
#     cout << " 17 tahun masih muda    : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata kamu masih muda ya,umurnya " << umur << "17 tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data

# %%
# !./input_data
# Out:
# Raffa maul (1 Kata) : ganteng
# 17 tahun masih muda    : tahun
#
# Halo ganteng, ternyata kamu masih muda ya,umurnya 017 tahun ya!
